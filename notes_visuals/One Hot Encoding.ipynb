# %% [markdown]
# # One Hot Encoding

# %%
import pandas as pd
import seaborn as sns

# %%
titanic = sns.load_dataset("titanic")
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# ## Encoding Class Column

# %%
titanic_class = pd.DataFrame(titanic["class"])
titanic_class
# Out:
#       class
# 0     Third
# 1     First
# 2     Third
# 3     First
# 4     Third
# ..      ...
# 886  Second
# 887   First
# 888   Third
# 889   First
# 890   Third
#
# [891 rows x 1 columns]

# %%
encoded_class = pd.get_dummies(titanic_class)
encoded_class.head()
# Out:
#    class_First  class_Second  class_Third
# 0            0             0            1
# 1            1             0            0
# 2            0             0            1
# 3            1             0            0
# 4            0             0            1

# %%
titanic.drop("class", axis = 1, inplace = True)
titanic = pd.concat([titanic, encoded_class], axis = 1)
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked    who  \
# 0         0       3    male  22.0      1      0   7.2500        S    man
# 1         1       1  female  38.0      1      0  71.2833        C  woman
# 2         1       3  female  26.0      0      0   7.9250        S  woman
# 3         1       1  female  35.0      1      0  53.1000        S  woman
# 4         0       3    male  35.0      0      0   8.0500        S    man
#
#    adult_male deck  embark_town alive  alone  class_First  class_Second  \
# 0        True  NaN  Southampton    no  False            0             0
# 1       False    C    Cherbourg   yes  False            1             0
# 2       False  NaN  Southampton   yes   True            0             0
# 3       False    C  Southampton   yes  False            1             0
# 4        True  NaN  Southampton    no   True            0             0
#
#    class_Third
# 0            1
# 1            0
# 2            1
# 3            0
# ...
